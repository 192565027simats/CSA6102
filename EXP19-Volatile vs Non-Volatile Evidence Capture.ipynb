# %% [markdown]
# <a href="https://colab.research.google.com/github/192565027simats/CSA6102/blob/main/EXP19-Volatile%20vs%20Non-Volatile%20Evidence%20Capture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import psutil

# Function to capture volatile evidence
def capture_volatile_evidence():
    processes = []

    for p in psutil.process_iter(['pid', 'name']):
        try:
            processes.append(p.info)
        except (psutil.NoSuchProcess,
                psutil.AccessDenied,
                psutil.ZombieProcess):
            pass

    return {
        "running_process_count": len(processes),
        "sample_processes": processes[:5],
    }

# Function to capture non-volatile evidence
def capture_nonvolatile_evidence(folder):
    files = sorted(os.listdir(folder))

    return {
        "disk_files": files,
        "file_count": len(files)
    }

# Folder containing evidence files
evidence_dir = "digital_evidence"

# Capture evidence
volatile_snapshot = capture_volatile_evidence()
nonvolatile_snapshot = capture_nonvolatile_evidence(evidence_dir)

# Display results
print("Volatile evidence -> running processes:",
      volatile_snapshot["running_process_count"])

print("Non-volatile evidence -> disk files:",
      nonvolatile_snapshot)
# Out:
# Volatile evidence -> running processes: 15
# Non-volatile evidence -> disk files: {'disk_files': ['browser_history.txt', 'chat_message.txt', 'email_log.txt', 'system_log.txt'], 'file_count': 4}
