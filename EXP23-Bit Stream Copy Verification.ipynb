# %% [markdown]
# <a href="https://colab.research.google.com/github/192565027simats/CSA6102/blob/main/EXP23-Bit%20Stream%20Copy%20Verification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import hashlib

# Create a sample evidence file (simulating a small storage device)
original_path = "original_evidence.bin"

with open(original_path, "wb") as f:
    f.write(os.urandom(1024))

# Perform a bit-stream copy
def bit_stream_copy(src_path, dst_path):
    with open(src_path, "rb") as src, open(dst_path, "wb") as dst:
        dst.write(src.read())

copy_path = "bitstream_copy.bin"
bit_stream_copy(original_path, copy_path)

# Calculate SHA-256 hash
def sha256_of_file(path):
    with open(path, "rb") as f:
        return hashlib.sha256(f.read()).hexdigest()

original_hash = sha256_of_file(original_path)
copy_hash = sha256_of_file(copy_path)

print("Original hash:", original_hash)
print("Copy hash:    ", copy_hash)

# Test Cases
def test_experiment6():
    assert os.path.getsize(original_path) == os.path.getsize(copy_path), \
        "Bit-stream copy must match original size exactly"

    assert original_hash == copy_hash, \
        "Hashes must match, proving the copy is forensically identical"

    print("All test cases passed.")

# Run the test cases
test_experiment6()
# Out:
# Original hash: ee0609aa91a9cc2545e6bc68f2846f5d6dd30023f71133fdc9250927876a0687
# Copy hash:     ee0609aa91a9cc2545e6bc68f2846f5d6dd30023f71133fdc9250927876a0687
# All test cases passed.
